# %%
import os
import shutil
import argparse

import warnings

warnings.filterwarnings(
    "ignore",
    module="pydantic"
)

import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn

from torch.serialization import add_safe_globals
from torch.utils.data import Dataset, DataLoader
from torch.distributions import Normal

import torchvision.models as models
import torchvision.transforms as T
import torchvision.transforms.functional as F

from PIL import Image

from sklearn.model_selection import train_test_split
from timm.models.vision_transformer import VisionTransformer
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, roc_curve

# %% [markdown]
# Loading the dataset:

# %%
df = pd.read_csv("/kaggle/input/chexchonet/chexchonet-a-chest-radiograph-dataset-with-gold-standard-echocardiography-labels-1.0.0/metadata.csv")

# %% [markdown]
# Creating the subset we'll be working with:

# %%
subset_path = "/kaggle/working/slvh_dataset"

if os.path.exists(subset_path):
    shutil.rmtree(subset_path)

os.makedirs(subset_path, exist_ok=True)
os.makedirs(os.path.join(subset_path, "images"), exist_ok=True)

# only slvh confirmed pacients and healthy ones
healthy      = df[(df.slvh == 0) & (df.dlv == 0)].sample(5518, random_state=42)
slvh_only    = df[(df.slvh == 1) & (df.dlv == 0)].sample(5518, random_state=42)

df_slvh_subset = pd.concat([healthy, slvh_only])

src_img_dir = "/kaggle/input/chexchonet/chexchonet-a-chest-radiograph-dataset-with-gold-standard-echocardiography-labels-1.0.0/images/"
dst_img_dir = os.path.join(subset_path, "images")

for _, row in df_slvh_subset.iterrows():
    src = os.path.join(src_img_dir, row["cxr_filename"])
    dst = os.path.join(dst_img_dir, row["cxr_filename"])
    shutil.copy(src, dst)

df_slvh_subset.to_csv(os.path.join(subset_path, "metadata_subset.csv"), index=False)

# %% [markdown]
# Creting the training, validation and testing sets:

# %%
train_df, temp_df = train_test_split(
    df_slvh_subset,
    test_size=0.10,
    random_state=42,
    shuffle=True,
    stratify=df_slvh_subset["slvh"]
)

val_df, test_df = train_test_split(
    temp_df,
    test_size=0.50,
    random_state=42,
    shuffle=True,
    stratify=temp_df["slvh"]
)

# %% [markdown]
# Class used for inputting the ViT:

# %%
class CheXchoNet(Dataset):
    def __init__(self, df, root_img_dir, transform=None):
        self.df = df.reset_index(drop=True)
        self.root_img_dir = root_img_dir
        self.transform = transform
        
    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        img_path = os.path.join(self.root_img_dir, row["cxr_filename"])

        img = Image.open(img_path).convert("RGB")
        if self.transform:
            img = self.transform(img)

        label = torch.tensor(row["slvh"], dtype=torch.float32)
        return img, label

# %% [markdown]
# Image preprocessing and augmentations steps for training, validation and testing sets:

# %%
transform = T.Compose([
    T.ToTensor(),
    T.Normalize([0.5]*3, [0.5]*3)
])

train_transform = T.Compose([
    T.ToTensor(),
    T.Normalize([0.5]*3, [0.5]*3),
    T.RandomHorizontalFlip(p=0.5),
    T.RandomRotation(degrees=15),
    T.RandomResizedCrop(size=224, scale=(0.8, 1.0), ratio=(0.9, 1.1))
])

# %% [markdown]
# Creating the corresponding DataLoaders:

# %%
root_img_dir = "/kaggle/working/slvh_dataset/images"

train_loader = DataLoader(
    CheXchoNet(train_df, root_img_dir, train_transform),
    batch_size=32, shuffle=True, num_workers=2
)

val_loader = DataLoader(
    CheXchoNet(val_df, root_img_dir, transform),
    batch_size=32, shuffle=False, num_workers=2
)

test_loader = DataLoader(
    CheXchoNet(test_df, root_img_dir, transform),
    batch_size=32, shuffle=False, num_workers=2
)

# %% [markdown]
# Loading the pretrained weights for the ViT:

# %%
weights_path = "/kaggle/input/vit-weights/vit-s_CXR_0.3M_mae.pth"

add_safe_globals([argparse.Namespace])
state = torch.load(weights_path, map_location="cpu", weights_only=False)

# %% [markdown]
# The vision transformer architecture used:

# %%
def vit_small_patch16(num_classes=0):
    model = VisionTransformer(
        patch_size=16,
        embed_dim=384,
        depth=12,
        num_heads=6,
        mlp_ratio=4,
        qkv_bias=True,
        norm_layer=nn.LayerNorm,
        num_classes=num_classes
    )
    return model

encoder = vit_small_patch16()

# loading the weights
encoder.load_state_dict(state["model"], strict=False)

# freezing the weights
for param in encoder.parameters():
    param.requires_grad = False

# %% [markdown]
# The MLP head used to classify:

# %%
class SLVHClassifier(nn.Module):
    def __init__(self, encoder):
        super().__init__()
        self.encoder = encoder

        self.mlp = nn.Sequential(
            nn.Linear(384, 512),
            nn.ReLU(),
            nn.Dropout(0.2),

            nn.Linear(512, 128),
            nn.ReLU(),
            nn.Dropout(0.2),

            nn.Linear(128, 1)
        )

    def forward(self, x):
        x = self.encoder(x)
        return self.mlp(x)

model = SLVHClassifier(encoder).cuda()

# %% [markdown]
# Optimizer and criterion used with the MLP:

# %%
criterion = nn.BCEWithLogitsLoss()

optimizer = torch.optim.AdamW(
    model.parameters(),
    lr=1e-4,
    weight_decay=1e-4
)

# %% [markdown]
# Linear learning rate warmup with cosine decay:

# %%
epochs = 20
warmup_epochs = 2

def lr_lambda(current_epoch):
    if current_epoch < warmup_epochs:
        return float(current_epoch) / float(max(1, warmup_epochs))

    progress = float(current_epoch - warmup_epochs) / float(max(1, epochs - warmup_epochs))
    return 0.5 * (1.0 + math.cos(math.pi * progress))

scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda)

# %% [markdown]
# Helper functions for the training loop:

# %%
def eval_loader(model, loader, criterion=None, device="cuda"):
    model.eval()
    total_loss = 0.0
    n_batches = 0

    probs_list = []
    labels_list = []

    with torch.no_grad():
        for x, y in loader:
            x = x.to(device, non_blocking=True)
            y = y.to(device, non_blocking=True)

            logits = model(x).squeeze(1)
            probs = torch.sigmoid(logits)

            probs_list.append(probs.detach().cpu())
            labels_list.append(y.detach().cpu())

            if criterion is not None:
                loss = criterion(logits, y)
                total_loss += loss.item()
                n_batches += 1

    probs_np = torch.cat(probs_list).numpy()
    labels_np = torch.cat(labels_list).numpy()

    auroc = roc_auc_score(labels_np, probs_np)

    avg_loss = (total_loss / n_batches) if (criterion is not None and n_batches > 0) else None
    return avg_loss, auroc, probs_np, labels_np

def train_one_epoch(model, loader, optimizer, criterion, device="cuda"):
    model.train()
    running_loss = 0.0

    probs_list = []
    labels_list = []

    for x, y in loader:
        x = x.to(device, non_blocking=True)
        y = y.to(device, non_blocking=True)

        optimizer.zero_grad(set_to_none=True)

        logits = model(x).squeeze(1)
        loss = criterion(logits, y)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

        probs = torch.sigmoid(logits)
        probs_list.append(probs.detach().cpu())
        labels_list.append(y.detach().cpu())

    avg_loss = running_loss / len(loader)
    probs_np = torch.cat(probs_list).numpy()
    labels_np = torch.cat(labels_list).numpy()
    auroc = roc_auc_score(labels_np, probs_np)

    return avg_loss, auroc

# %% [markdown]
# The training loop:

# %%
best_auc = 0
patience = 5
patience_counter = 0

train_losses, val_losses = [], []
train_aucs, val_aucs = [], []

for epoch in range(epochs):
    train_loss, train_auc = train_one_epoch(model, train_loader, optimizer, criterion, device="cuda")
    scheduler.step()

    val_loss, val_auc, _, _ = eval_loader(model, val_loader, criterion=criterion, device="cuda")

    train_losses.append(train_loss)
    train_aucs.append(train_auc)
    val_losses.append(val_loss)
    val_aucs.append(val_auc)

    print(
        f"Epoch {epoch+1}/{epochs} | "
        f"Train Loss: {train_loss:.4f} | "
        f"Val Loss: {val_loss:.4f} | "
        f"Train AUROC: {train_auc:.4f} | "
        f"Val AUROC: {val_auc:.4f}"
    )

    if val_auc > best_auc:
        best_auc = val_auc
        patience_counter = 0
        torch.save(model.state_dict(), "best_slvh_model.pth")
        print(">> New best model saved!")
    else:
        patience_counter += 1
        if patience_counter >= patience:
            print("Early stopping triggered.")
            break
# Out:
# Epoch 1/20 | Train Loss: 0.6936 | Val Loss: 0.6929 | Train AUROC: 0.4910 | Val AUROC: 0.5040
# >> New best model saved!
# Epoch 2/20 | Train Loss: 0.6751 | Val Loss: 0.6638 | Train AUROC: 0.6330 | Val AUROC: 0.6312
# >> New best model saved!
# Epoch 3/20 | Train Loss: 0.6327 | Val Loss: 0.6445 | Train AUROC: 0.6945 | Val AUROC: 0.6827
# >> New best model saved!
# Epoch 4/20 | Train Loss: 0.6158 | Val Loss: 0.6449 | Train AUROC: 0.7184 | Val AUROC: 0.6968
# >> New best model saved!
# Epoch 5/20 | Train Loss: 0.6055 | Val Loss: 0.6344 | Train AUROC: 0.7317 | Val AUROC: 0.7087
# >> New best model saved!
# Epoch 6/20 | Train Loss: 0.5997 | Val Loss: 0.6232 | Train AUROC: 0.7377 | Val AUROC: 0.7168
# >> New best model saved!
# Epoch 7/20 | Train Loss: 0.5951 | Val Loss: 0.6229 | Train AUROC: 0.7430 | Val AUROC: 0.7189
# >> New best model saved!
# Epoch 8/20 | Train Loss: 0.5905 | Val Loss: 0.6434 | Train AUROC: 0.7494 | Val AUROC: 0.7239
# >> New best model saved!
# Epoch 9/20 | Train Loss: 0.5900 | Val Loss: 0.6165 | Train AUROC: 0.7484 | Val AUROC: 0.7283
# >> New best model saved!
# Epoch 10/20 | Train Loss: 0.5847 | Val Loss: 0.6172 | Train AUROC: 0.7541 | Val AUROC: 0.7269
# Epoch 11/20 | Train Loss: 0.5836 | Val Loss: 0.6111 | Train AUROC: 0.7556 | Val AUROC: 0.7330
# >> New best model saved!
# Epoch 12/20 | Train Loss: 0.5800 | Val Loss: 0.6118 | Train AUROC: 0.7599 | Val AUROC: 0.7321
# Epoch 13/20 | Train Loss: 0.5791 | Val Loss: 0.6101 | Train AUROC: 0.7615 | Val AUROC: 0.7345
# >> New best model saved!
# Epoch 14/20 | Train Loss: 0.5774 | Val Loss: 0.6084 | Train AUROC: 0.7621 | Val AUROC: 0.7365
# >> New best model saved!
# Epoch 15/20 | Train Loss: 0.5753 | Val Loss: 0.6082 | Train AUROC: 0.7653 | Val AUROC: 0.7360
# Epoch 16/20 | Train Loss: 0.5736 | Val Loss: 0.6080 | Train AUROC: 0.7661 | Val AUROC: 0.7377
# >> New best model saved!
# Epoch 17/20 | Train Loss: 0.5728 | Val Loss: 0.6078 | Train AUROC: 0.7671 | Val AUROC: 0.7370
# Epoch 18/20 | Train Loss: 0.5700 | Val Loss: 0.6085 | Train AUROC: 0.7707 | Val AUROC: 0.7376
# Epoch 19/20 | Train Loss: 0.5713 | Val Loss: 0.6081 | Train AUROC: 0.7682 | Val AUROC: 0.7377
# Epoch 20/20 | Train Loss: 0.5716 | Val Loss: 0.6081 | Train AUROC: 0.7682 | Val AUROC: 0.7376

# %% [markdown]
# Saving the best model after the training phase:

# %%
best_model = SLVHClassifier(encoder).cuda()
best_model.load_state_dict(torch.load("best_slvh_model.pth"))
# Out:
# <All keys matched successfully>

# %% [markdown]
# Running the model on the test set:

# %%
all_probs = []
all_preds = []
all_labels = []

with torch.no_grad():
    for x, y in test_loader:
        x = x.cuda()
        y = y.cuda()

        logits = best_model(x).squeeze(1)
        probs = torch.sigmoid(logits)

        preds = (probs > 0.5).long()

        all_probs.append(probs.cpu())
        all_preds.append(preds.cpu())
        all_labels.append(y.cpu())

all_probs = torch.cat(all_probs).numpy()
all_preds = torch.cat(all_preds).numpy()
all_labels = torch.cat(all_labels).numpy()

# %% [markdown]
# Visualizing the training and test results:

# %%
epochs_range = range(1, len(train_aucs) + 1)

plt.figure(figsize=(8, 4))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, train_losses, label='Train Loss')
plt.plot(epochs_range, val_losses, label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss vs Epoch')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(epochs_range, train_aucs, label='Train AUROC')
plt.plot(epochs_range, val_aucs, label='Val AUROC')
plt.xlabel('Epoch')
plt.ylabel('AUROC')
plt.title('AUROC vs Epoch')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
test_auc = roc_auc_score(all_labels, all_probs)
test_precision = precision_score(all_labels, all_preds)
test_recall = recall_score(all_labels, all_preds)
test_f1 = f1_score(all_labels, all_preds)

print("\nTest Set Performance")
print("------------------------")
print(f"AUROC:     {test_auc:.4f}")
print(f"Precision: {test_precision:.4f}")
print(f"Recall:    {test_recall:.4f}")
print(f"F1-score:  {test_f1:.4f}")
# Out:
# Test Set Performance
# ------------------------
# AUROC:     0.7807
# Precision: 0.6990
# Recall:    0.7572
# F1-score:  0.7270
